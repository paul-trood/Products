# %%
import pandas as pd
import os
import glob

path = r"...\whisky" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

# Read csv files for each one in the file path
df_from_each_file = (pd.read_csv(f) for f in all_files)

# Concatenate dataframes
concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)

# %%
concatenated_df.head()
# Out:
#                                    name                              style  \
# 0  Jack Daniel's Old No. 7\nGuitar Case                  Tennessee Whiskey
# 1                Eagle Rare 10 Year Old  Kentucky Straight Bourbon Whiskey
# 2   Woodford Reserve Distiller's Select  Kentucky Straight Bourbon Whiskey
# 3         Gentleman Jack\nJack Daniel's                  Tennessee Whiskey
# 4                Wild Turkey Longbranch  Kentucky Straight Bourbon Whiskey
#
#    size alohol_percentage                  rating  in_stock   price  \
# 0  70cl               40%      5\n\n\n(2 Reviews)  In Stock  £39.95
# 1  70cl               45%   4.5\n\n\n(51 Reviews)  In Stock  £40.45
# 2  70cl             43.2%     5\n\n\n(97 Reviews)  In Stock  £35.95
# 3  70cl               40%  4.5\n\n\n(230 Reviews)  In Stock  £32.95
# 4  70cl               43%     4\n\n\n(13 Reviews)  In Stock  £38.45
#
#       price_per_litre customer_item_limit  \
# 0  (£57.07 per litre)            no limit
# 1  (£57.79 per litre)            no limit
# 2  (£51.36 per litre)            no limit
# 3  (£47.07 per litre)            no limit
# 4  (£54.93 per litre)            no limit
#
#                                          description date_scraped  \
# 0  A bottle of Jack Daniel's Old No. 7, presented...   2022-06-17
# 1  A top-quality bourbon from Buffalo Trace, the ...   2022-06-17
# 2  Woodford Reserve is a superbly smooth, flavour...   2022-06-17
# 3  Twice run through Jack Daniels’ trademark mapl...   2022-06-17
# 4  A full-bodied and balanced bourbon, at once fr...   2022-06-17
#
#          country
# 0  United States
# 1  United States
# 2  United States
# 3  United States
# 4  United States

# %%
concatenated_df.tail()
# Out:
#                                                   name  \
# 827                             Kavalan Ex-Bourbon Oak
# 828  Kavalan Solist Port Cask #015A (2010)\n10 Year...
# 829                         Kavalan King Car Conductor
# 830      Kavalan Concertmaster\nPort Finish Half Litre
# 831         Kavalan Solist Moscatel Cask #031A\n(2010)
#
#                                                  style  size  \
# 827  Taiwanese Single Malt Whisky\nDistillery Bottling  70cl
# 828  Taiwanese Single Malt Whisky\nDistillery Bottling  70cl
# 829                       Taiwanese Single Malt Whisky  70cl
# 830                       Single Malt Taiwanese Whisky  50cl
# 831  Taiwanese Single Malt Whisky\nDistillery Bottling  70cl
#
#     alohol_percentage             rating  in_stock   price  \
# 827               46%          no rating  In Stock  £84.45
# 828             56.3%          no rating  In Stock    £159
# 829               46%  4\n\n\n(1 Review)  In Stock  £81.95
# 830               40%  5\n\n\n(1 Review)  In Stock  £51.95
# 831             56.3%          no rating  In Stock    £370
#
#          price_per_litre customer_item_limit  \
# 827  (£120.64 per litre)            no limit
# 828  (£227.14 per litre)            no limit
# 829  (£117.07 per litre)            no limit
# 830  (£103.90 per litre)            no limit
# 831  (£528.57 per litre)            no limit
#
#                                            description date_scraped country
# 827  A Taiwanese single malt from Kavalan distiller...   2022-06-17  Taiwan
# 828  A 2010 Kavalan Taiwanese single malt that was ...   2022-06-17  Taiwan
# 829  A single malt whisky from King Car's Kavalan d...   2022-06-17  Taiwan
# 830  A half-litre bottle of port-finished whisky fr...   2022-06-17  Taiwan
# 831  Released in 2016, this bottling of Kavalan Sol...   2022-06-17  Taiwan
